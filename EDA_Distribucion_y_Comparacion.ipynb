# %% [markdown]
# <a href="https://colab.research.google.com/github/apchavezr/VISUALIZACION_DATOS_TOMA-DECISIONES/blob/main/EDA_Distribucion_y_Comparacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 🎯 Objetivo del ejercicio
#
# El objetivo de este ejercicio es ilustrar cómo utilizar visualizaciones estadísticas básicas —como histogramas, diagramas de densidad, boxplots y gráficos de violín— para analizar la distribución de una variable y comparar dicha variable entre diferentes grupos categóricos. Estas representaciones permiten identificar patrones, simetrías, asimetrías, valores atípicos y diferencias entre subgrupos, lo cual es clave en el análisis exploratorio de datos (EDA) antes de aplicar técnicas estadísticas más formales.

# %% [markdown]
# ## 📘 Enseñanza del ejercicio
#
# A través de este ejercicio, el estudiante podrá reconocer que las decisiones analíticas deben estar fundamentadas en una comprensión visual previa del comportamiento de los datos. Al comparar gráficamente una variable cuantitativa entre distintos grupos, se aprende a:
#
# - Seleccionar el tipo de gráfico adecuado según el propósito del análisis (distribución o comparación).
# - Interpretar características clave de las distribuciones como mediana, dispersión, asimetría y presencia de outliers.
# - Detectar patrones o diferencias que puedan orientar la formulación de hipótesis o justificar intervenciones en contextos aplicados, como la evaluación institucional o el análisis de encuestas.

# %% [markdown]
# # Análisis de Distribución y Comparación entre Grupos con Visualización Gráfica
#
# Este cuaderno presenta un ejemplo básico sobre cómo analizar la **distribución de una variable** y cómo **comparar esa variable entre grupos categóricos**, utilizando gráficos como histogramas, diagramas de densidad, gráficos de caja y gráficos de violín.
#
# Se simulan datos de puntajes en una prueba de comprensión lectora en dos colegios diferentes, y se explora visualmente la información.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# Simulación
np.random.seed(10)
n = 100
data = pd.DataFrame({
    'Colegio': ['A'] * (n // 2) + ['B'] * (n // 2),
    'Puntaje': np.concatenate([
        np.random.normal(70, 10, n // 2),  # Colegio A
        np.random.normal(75, 8, n // 2)    # Colegio B
    ])
})

data.head()
# Out:
#   Colegio    Puntaje
# 0       A  83.315865
# 1       A  77.152790
# 2       A  54.545997
# 3       A  69.916162
# 4       A  76.213360

# %%
plt.figure(figsize=(10, 5))
sns.histplot(data['Puntaje'], kde=True, bins=15, color='lightblue')
plt.title('Distribución general de puntajes')
plt.xlabel('Puntaje')
plt.ylabel('Frecuencia')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x='Colegio', y='Puntaje', data=data, palette='pastel')
plt.title('Distribución de puntajes por colegio (Boxplot)')
plt.xlabel('Colegio')
plt.ylabel('Puntaje')
plt.show()
# Out:
# <ipython-input-3-524f11f82b38>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Colegio', y='Puntaje', data=data, palette='pastel')

# %%
plt.figure(figsize=(10, 5))
sns.violinplot(x='Colegio', y='Puntaje', data=data, palette='muted')
plt.title('Distribución de puntajes por colegio (Gráfico de violín)')
plt.xlabel('Colegio')
plt.ylabel('Puntaje')
plt.show()
# Out:
# <ipython-input-4-d9fc29903007>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Colegio', y='Puntaje', data=data, palette='muted')

# %% [markdown]
# ## Conclusiones
#
# - El **histograma con densidad** permite observar la forma general de la distribución de los puntajes, incluyendo concentración y simetría.
# - El **boxplot** muestra la mediana, rango intercuartílico y valores atípicos para cada colegio.
# - El **gráfico de violín** permite observar visualmente la forma completa de la distribución en cada grupo, resaltando diferencias en densidad y dispersión.
# - Este tipo de visualización es útil en análisis educativos y comparativos, ayudando a orientar decisiones antes de aplicar técnicas estadísticas formales.
